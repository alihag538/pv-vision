# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from pv_vision.crack_analysis.crackcell import CrackCell

image_dir = Path("") # Path to the directory containing the images
ann_dir = Path("") # Path to the directory containing the masks
output_dir = Path("") # Path to the directory where the output will be saved

output_dir.mkdir(parents=True, exist_ok=True) #Create output folder if it doesn't exist

results = [] # Store feature results for each image
for img_path in sorted(image_dir.glob("*.jpg")):
    name = img_path.stem
    ann_path = ann_dir / f"{name}.png"

    if not ann_path.exists():
        print(f"Skipping {name}: no annotation found")
        continue

    cell = CrackCell(img_path, ann_path)
